# %% [markdown]
# [参考サイト](https://www.philschmid.de/bert-text-classification-in-a-different-language)

# %%
# install simpletransformers
# !pip install simpletransformers
 
# check installed version
# !pip freeze | grep simpletransformers
# simpletransformers==0.28.2
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.70.1-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from simpletransformers) (2.0.0)
# Collecting requests (from simpletransformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.47.0 (from simpletransformers)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting regex (from simpletransformers)
#   Using cached regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting transformers>=4.31.0 (from simpletransformers)
#   Using cached transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
# Collecting datasets (from simpletransformers)
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from simpletransformers) (1.14.0)
# Requirement already satisfied: scikit-learn in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from simpletransformers) (1.5.0)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tensorboard (from simpletransformers)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboardx (from simpletransformers)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting pandas (from simpletransformers)
#   Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting tokenizers (from simpletransformers)
#   Using cached tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.17.4-py3-none-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.36.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting sentencepiece (from simpletransformers)
#   Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting filelock (from transformers>=4.31.0->simpletransformers)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers>=4.31.0->simpletransformers)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Collecting numpy (from simpletransformers)
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from transformers>=4.31.0->simpletransformers) (24.1)
# Collecting pyyaml>=5.1 (from transformers>=4.31.0->simpletransformers)
#   Using cached PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.31.0->simpletransformers)
#   Using cached safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb>=0.10.32->simpletransformers)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers) (4.2.2)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading protobuf-5.27.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Requirement already satisfied: psutil>=5.0.0 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from wandb>=0.10.32->simpletransformers) (6.0.0)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-2.8.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.3-cp312-cp312-macosx_10_9_universal2.whl.metadata (9.9 kB)
# Collecting setuptools (from wandb>=0.10.32->simpletransformers)
#   Using cached setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests->simpletransformers)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->simpletransformers)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->simpletransformers)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->simpletransformers)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting pyarrow>=15.0.0 (from datasets->simpletransformers)
#   Downloading pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets->simpletransformers)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->simpletransformers)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->simpletransformers)
#   Downloading xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->simpletransformers)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets->simpletransformers)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->simpletransformers)
#   Downloading aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from pandas->simpletransformers) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->simpletransformers)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->simpletransformers)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from scikit-learn->simpletransformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from scikit-learn->simpletransformers) (3.5.0)
# Collecting altair<6,>=4.0 (from streamlit->simpletransformers)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->simpletransformers)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->simpletransformers)
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pillow<11,>=7.1.0 (from streamlit->simpletransformers)
#   Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting rich<14,>=10.14.0 (from streamlit->simpletransformers)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit->simpletransformers)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->simpletransformers)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions<5,>=4.3.0 (from streamlit->simpletransformers)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from streamlit->simpletransformers) (6.4.1)
# Collecting absl-py>=0.4 (from tensorboard->simpletransformers)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->simpletransformers)
#   Using cached grpcio-1.64.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard->simpletransformers)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: six>1.9 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from tensorboard->simpletransformers) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->simpletransformers)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->simpletransformers)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting jinja2 (from altair<6,>=4.0->streamlit->simpletransformers)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets->simpletransformers)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Downloading frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Downloading multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->simpletransformers)
#   Downloading yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->simpletransformers)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/master/Documents/git-project/24master/sklearn-env/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.18.0)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard->simpletransformers)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers)
#   Downloading rpds_py-0.19.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading simpletransformers-0.70.1-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 8.4 MB/s eta 0:00:00
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached transformers-4.42.3-py3-none-any.whl (9.3 MB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Using cached regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl (278 kB)
# Using cached tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
# Downloading wandb-0.17.4-py3-none-macosx_11_0_arm64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 11.4 MB/s eta 0:00:0000:0100:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 10.2 MB/s eta 0:00:00a 0:00:01
# Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
# Downloading sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.0 MB/s eta 0:00:0000:01:00:01
# Downloading streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.3 MB/s eta 0:00:00
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 10.2 MB/s eta 0:00:0000:0100:01
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 7.8 MB/s eta 0:00:00
# Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.1 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 9.1 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl (392 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.4/392.4 kB 8.0 MB/s eta 0:00:00:00:01
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 8.8 MB/s eta 0:00:00
# Using cached grpcio-1.64.1-cp312-cp312-macosx_10_9_universal2.whl (10.3 MB)
# Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.3 MB/s eta 0:00:0000:0100:01
# Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl (26.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 11.5 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 11.4 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl (165 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl (411 kB)
# Downloading sentry_sdk-2.8.0-py2.py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 9.0 MB/s eta 0:00:00
# Using cached setuptools-70.2.0-py3-none-any.whl (930 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 8.0 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading setproctitle-1.3.3-cp312-cp312-macosx_10_9_universal2.whl (16 kB)
# Downloading xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.6 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.5 MB/s eta 0:00:00
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 6.1 MB/s eta 0:00:00
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl (18 kB)
# Downloading multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Downloading yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 3.8 MB/s eta 0:00:00
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 3.9 MB/s eta 0:00:00
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.19.0-cp312-cp312-macosx_11_0_arm64.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 kB 9.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (pyproject.toml) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=2c8e056c90b5cc56a1fcad51ec18c3f19cd1d1f58a3d6e8b8a568c4d2f383a98
#   Stored in directory: /Users/master/Library/Caches/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: sentencepiece, pytz, xxhash, urllib3, tzdata, typing-extensions, tqdm, toolz, toml, tensorboard-data-server, tenacity, smmap, setuptools, setproctitle, safetensors, rpds-py, regex, pyyaml, pyarrow-hotfix, protobuf, pillow, numpy, multidict, mdurl, MarkupSafe, markdown, idna, grpcio, fsspec, frozenlist, filelock, docker-pycreds, dill, click, charset-normalizer, certifi, cachetools, blinker, attrs, absl-py, yarl, werkzeug, tensorboardx, sentry-sdk, requests, referencing, pyarrow, pandas, multiprocess, markdown-it-py, jinja2, gitdb, aiosignal, tensorboard, rich, pydeck, jsonschema-specifications, huggingface-hub, gitpython, aiohttp, wandb, tokenizers, seqeval, jsonschema, transformers, datasets, altair, streamlit, simpletransformers
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 aiohttp-3.9.5 aiosignal-1.3.1 altair-5.3.0 attrs-23.2.0 blinker-1.8.2 cachetools-5.3.3 certifi-2024.7.4 charset-normalizer-3.3.2 click-8.1.7 datasets-2.20.0 dill-0.3.8 docker-pycreds-0.4.0 filelock-3.15.4 frozenlist-1.4.1 fsspec-2024.5.0 gitdb-4.0.11 gitpython-3.1.43 grpcio-1.64.1 huggingface-hub-0.23.4 idna-3.7 jinja2-3.1.4 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.0.5 multiprocess-0.70.16 numpy-1.26.4 pandas-2.2.2 pillow-10.4.0 protobuf-4.25.3 pyarrow-16.1.0 pyarrow-hotfix-0.6 pydeck-0.9.1 pytz-2024.1 pyyaml-6.0.1 referencing-0.35.1 regex-2024.5.15 requests-2.32.3 rich-13.7.1 rpds-py-0.19.0 safetensors-0.4.3 sentencepiece-0.2.0 sentry-sdk-2.8.0 seqeval-1.2.2 setproctitle-1.3.3 setuptools-70.2.0 simpletransformers-0.70.1 smmap-5.0.1 streamlit-1.36.0 tenacity-8.5.0 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorboardx-2.6.2.2 tokenizers-0.19.1 toml-0.10.2 toolz-0.12.1 tqdm-4.66.4 transformers-4.42.3 typing-extensions-4.12.2 tzdata-2024.1 urllib3-2.2.2 wandb-0.17.4 werkzeug-3.0.3 xxhash-3.4.1 yarl-1.9.4
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# simpletransformers==0.70.1

# %%
# !wget https://projects.fzai.h-da.de/iggsa/wp-content/uploads/2019/08/germeval2019GoldLabelsSubtask1_2.txt
# !wget https://projects.fzai.h-da.de/iggsa/wp-content/uploads/2019/09/germeval2019.training_subtask1_2_korrigiert.txt
# Out:
# --2024-07-09 08:52:43--  https://projects.fzai.h-da.de/iggsa/wp-content/uploads/2019/08/germeval2019GoldLabelsSubtask1_2.txt
# projects.fzai.h-da.de (projects.fzai.h-da.de) をDNSに問いあわせています... 141.100.10.111, 2001:67c:2184:fdfe::111
# projects.fzai.h-da.de (projects.fzai.h-da.de)|141.100.10.111|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 301 Moved Permanently
# 場所: https://fz.h-da.de/iggsa//wp-content/uploads/2019/08/germeval2019GoldLabelsSubtask1_2.txt [続く]
# --2024-07-09 08:52:44--  https://fz.h-da.de/iggsa//wp-content/uploads/2019/08/germeval2019GoldLabelsSubtask1_2.txt
# fz.h-da.de (fz.h-da.de) をDNSに問いあわせています... 141.100.10.111, 2001:67c:2184:fdfe::111
# fz.h-da.de (fz.h-da.de)|141.100.10.111|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 404 Not Found
# 2024-07-09 08:52:45 エラー 404: Not Found。
#
# --2024-07-09 08:52:45--  https://projects.fzai.h-da.de/iggsa/wp-content/uploads/2019/09/germeval2019.training_subtask1_2_korrigiert.txt
# projects.fzai.h-da.de (projects.fzai.h-da.de) をDNSに問いあわせています... 141.100.10.111, 2001:67c:2184:fdfe::111
# projects.fzai.h-da.de (projects.fzai.h-da.de)|141.100.10.111|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 301 Moved Permanently
# 場所: https://fz.h-da.de/iggsa//wp-content/uploads/2019/09/germeval2019.training_subtask1_2_korrigiert.txt [続く]
# --2024-07-09 08:52:46--  https://fz.h-da.de/iggsa//wp-content/uploads/2019/09/germeval2019.training_subtask1_2_korrigiert.txt
# fz.h-da.de (fz.h-da.de) をDNSに問いあわせています... 141.100.10.111, 2001:67c:2184:fdfe::111
# fz.h-da.de (fz.h-da.de)|141.100.10.111|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 404 Not Found
# 2024-07-09 08:52:47 エラー 404: Not Found。

# %%
import pandas as pd
 
class_list = ['INSULT','ABUSE','PROFANITY','OTHER']
 
df1 = pd.read_csv('germeval2019GoldLabelsSubtask1_2.txt',sep='\t', lineterminator='\n',encoding='utf8',names=["tweet", "task1", "task2"])
df2 = pd.read_csv('germeval2019.training_subtask1_2_korrigiert.txt',sep='\t', lineterminator='\n',encoding='utf8',names=["tweet", "task1", "task2"])
 
df = pd.concat([df1,df2])
df['task2'] = df['task2'].str.replace('\r', "")
df['pred_class'] = df.apply(lambda x:  class_list.index(x['task2']),axis=1)
 
df = df[['tweet','pred_class']]
 
print(df.shape)
df.head()

# %%
from sklearn.model_selection import train_test_split
 
train_df, test_df = train_test_split(df, test_size=0.10)
 
print('train shape: ',train_df.shape)
print('test shape: ',test_df.shape)
 
# train shape:  (6309, 2)
# test shape:  (702, 2)

# %%
from simpletransformers.classification import ClassificationModel
 
# define hyperparameter
train_args ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 4}
 
# Create a ClassificationModel
model = ClassificationModel(
    "bert", "distilbert-base-german-cased",
    num_labels=4,
    args=train_args
)

# %%
model.train_model(train_df)

# %%
from sklearn.metrics import f1_score, accuracy_score
 
def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='micro')
 
result, model_outputs, wrong_predictions = model.eval_model(test_df, f1=f1_multiclass, acc=accuracy_score)
 
# {'acc': 0.6894586894586895,
# 'eval_loss': 0.8673831869594075,
# 'f1': 0.6894586894586895,
# 'mcc': 0.25262380289641617}

# %%
import os
import tarfile
 
def pack_model(model_path='',file_name=''):
  files = [files for root, dirs, files in os.walk(model_path)][0]
  with tarfile.open(file_name+ '.tar.gz', 'w:gz') as f:
    for file in files:
      f.add(f'{model_path}/{file}')
 
# run the function
pack_model('output_path','model_name')

# %%
import os
import tarfile
 
def unpack_model(model_name=''):
  tar = tarfile.open(f"{model_name}.tar.gz", "r:gz")
  tar.extractall()
  tar.close()
 
unpack_model('model_name')

# %%
from simpletransformers.classification import ClassificationModel
 
# define hyperparameter
train_args ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 4}
 
# Create a ClassificationModel with our trained model
model = ClassificationModel(
    "bert", 'path_to_model/',
    num_labels=4,
    args=train_args
)

# %%
class_list = ['INSULT','ABUSE','PROFANITY','OTHER']
 
test_tweet1 = "Meine Mutter hat mir erzählt, dass mein Vater einen Wahlkreiskandidaten nicht gewählt hat, weil der gegen die Homo-Ehe ist"
 
predictions, raw_outputs = model.predict([test_tweet1])
 
print(class_list[predictions[0]])
# OTHER
test_tweet2 = "Frau #Böttinger meine Meinung dazu ist sie sollten uns mit ihrem Pferdegebiss nicht weiter belästigen #WDR"
 
predictions, raw_outputs = model.predict([test_tweet2])
 
print(class_list[predictions[0]])
# INSULT
